# %% [markdown]
# # STUDENT MARK LIST

# %% [markdown]
# ## SUBJECT WISE OVER ALL MARK

# %%
student1 = "Anush";
student2 = "Brindha";
student3 = "Kowshik";
student4 = "Judith";
student5 = "Lisa";

serialNumber = "S.No.";
studentName = "Name";
firstLanguage = "1.Language";
secondLanguage = "2.Language";
subjectMaths = "3.Maths";
subjectPhysics = "4.Physics";
subjectChemistry = "5.Chemistry";
subjectBiology = "6.Biology";

total = "Total";


anushFirstLanScore = 75;
anushSecondLanScore = 88;
anushMathsScore = 91;
anushPhysicsScore = 70;
anushChemistryScore = 100;
anushBiologyScore = 93;

brindhaFirstLanScore = 80;
brindhaSecondLanScore = 90;
brindhaMathsLanScore = 76;
brindhaPhysicsLanScore = 66;
brindhaChemistryLanScore = 98;
brindhaBiologyLanScore = 95;

kowshikFirstLanScore = 72;
kowshikSecondLanScore = 90;
kowshikMathsLanScore = 99;
kowshikPhysicsLanScore = 100;
kowshikChemistryLanScore = 85;
kowshikBiologyLanScore = 95;

judithFirstLanScore = 79;
judithSecondLanScore = 87;
judithMathsLanScore = 85;
judithPhysicsLanScore = 100;
judithChemistryLanScore = 90;
judithBiologyLanScore = 89;

lisaFirstLanScore = 81;
lisaSecondLanScore = 70;
lisaMathsLanScore = 93;
lisaPhysicsLanScore = 99;
lisaChemistryLanScore = 95;
lisaBiologyLanScore = 100;



anushTotal =  anushFirstLanScore + anushSecondLanScore + anushMathsScore + anushPhysicsScore + anushChemistryScore + anushBiologyScore;
brindhaTotal = brindhaFirstLanScore +  brindhaSecondLanScore + brindhaMathsLanScore + brindhaPhysicsLanScore + brindhaChemistryLanScore + brindhaBiologyLanScore;
kowshikTotal = kowshikFirstLanScore + kowshikSecondLanScore + kowshikMathsLanScore + kowshikPhysicsLanScore + kowshikChemistryLanScore + kowshikBiologyLanScore; 
judithTotal = judithFirstLanScore + judithSecondLanScore + judithMathsLanScore + judithPhysicsLanScore + judithChemistryLanScore + judithBiologyLanScore;
lisaTotal = lisaFirstLanScore + lisaSecondLanScore + lisaMathsLanScore + lisaPhysicsLanScore + lisaChemistryLanScore + lisaBiologyLanScore;





overAllTatal = anushTotal + brindhaTotal + kowshikTotal + judithTotal + lisaTotal;

subjectWiseTotal = "Subject Wise Total";

fightLanOverallTotal = anushFirstLanScore + brindhaFirstLanScore + kowshikFirstLanScore + judithFirstLanScore + lisaFirstLanScore;
secondLanOverallTotal = anushSecondLanScore + brindhaSecondLanScore + kowshikSecondLanScore + judithSecondLanScore + lisaSecondLanScore;
mathsOverallTotal = anushMathsScore + brindhaMathsLanScore + kowshikMathsLanScore + judithMathsLanScore + lisaMathsLanScore;
physicsOverallTotal = anushPhysicsScore + brindhaPhysicsLanScore + kowshikPhysicsLanScore + judithPhysicsLanScore + lisaPhysicsLanScore;
chemistryOverallTotal = anushChemistryScore + brindhaChemistryLanScore + kowshikChemistryLanScore + judithChemistryLanScore + lisaChemistryLanScore;
biologyOverallTotal =  anushBiologyScore + brindhaBiologyLanScore + kowshikBiologyLanScore + judithBiologyLanScore + lisaBiologyLanScore;





serialNo1 = 1;
serialNo2 = 2;
serialNo3 = 3;
serialNo4 = 4;
serialNo5 = 5;

print(serialNumber, "  ", studentName, "  ", firstLanguage, "  ", secondLanguage, "  ", subjectMaths, "  ", subjectPhysics, "  ", subjectChemistry, "  ", subjectBiology, "  ", Total,"\n");

print(serialNo1, "      ", student1, "      ", anushFirstLanScore, "          ", anushSecondLanScore, "        ", anushMathsScore, "        ", anushPhysicsScore, "         ", anushChemistryScore, "          ", anushBiologyScore, "      ", anushTotal,"\n");

print(serialNo2, "      ", student2, "    ", brindhaFirstLanScore, "          ", brindhaSecondLanScore, "        ", brindhaMathsLanScore, "        ", brindhaPhysicsLanScore, "          ", brindhaChemistryLanScore, "          ", brindhaBiologyLanScore, "      ", brindhaTotal,"\n");

print(serialNo3, "      ", student3, "    ", kowshikFirstLanScore, "          ", kowshikSecondLanScore, "        ", kowshikMathsLanScore, "        ", kowshikPhysicsLanScore, "         ", kowshikChemistryLanScore, "          ", kowshikBiologyLanScore, "      ", kowshikTotal,"\n");

print(serialNo4, "      ", student4, "     ", judithFirstLanScore, "          ", judithSecondLanScore, "        ", judithMathsLanScore, "        ", judithPhysicsLanScore, "         ", judithChemistryLanScore, "          ", judithBiologyLanScore, "      ", judithTotal,"\n");

print(serialNo5, "      ", student5, "       ", lisaFirstLanScore, "          ", lisaSecondLanScore, "        ", lisaMathsLanScore, "        ", lisaPhysicsLanScore, "          ", lisaChemistryLanScore, "          ", lisaBiologyLanScore, "     ", lisaTotal,"\n");

print("             ", "     ", "______", "      ", "______", "    ", "______", "    ", "______", "      ", "______", "       ", "______", "  ", "________","\n");

print("Overall Score","      ", fightLanOverallTotal, "          ", secondLanOverallTotal, "       ", mathsOverallTotal, "      ", physicsOverallTotal,"         ", chemistryOverallTotal,"          ", biologyOverallTotal, "      ", overAllTatal);
# Out:
# S.No.    Name    1.Language    2.Language    3.Maths    4.Physics    5.Chemistry    6.Biology    Total
#
# 1        Anush        75            88          91          70           100            93        517
#
# 2        Brindha      80            90          76          66            98            95        505
#
# 3        Kowshik      72            90          99          100           85            95        541
#
# 4        Judith       79            87          85          100           90            89        530
#
# 5        Lisa         81            70          93          99            95            100       538
#
#                     ______        ______      ______      ______        ______         ______    ________
#
# Overall Score        387            425         444        435           468            472        2631
